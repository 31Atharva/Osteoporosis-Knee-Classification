# %% [markdown]
# # KNEE X RAY CLASSIFICATION

# %% [markdown]
# This project focuses on developing a machine learning-based classification model to identify and classify knee conditions associated with osteoporosis. By leveraging advanced data science techniques, the goal is to automate the diagnosis process, making it more efficient and accurate compared to traditional manual assessments.

# %%
import sys
print(sys.executable)
# Out:
# /Users/atharvadumbre/Osteoporosis_knee_Classification-main/osteoporosis-knee-env/bin/python

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from PIL import Image,ImageEnhance
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from matplotlib.image import imread
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import load_model
import warnings
warnings.filterwarnings('ignore')

# %%
import kagglehub

path = kagglehub.dataset_download("sachinkumar413/osteoporosis-knee-dataset-preprocessed128x256")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/atharvadumbre/.cache/kagglehub/datasets/sachinkumar413/osteoporosis-knee-dataset-preprocessed128x256/versions/1

# %%
os.listdir(path)
# Out:
# ['Osteoporosis Knee Dataset']

# %%
data_dir = r'/Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset'

# %%
os.listdir(data_dir)
# Out:
# ['.DS_Store', 'Osteoporosis', 'Normal']

# %% [markdown]
# # Visualizing  osteoporosis images

# %%
import os

# Define data_dir
data_dir = r'/Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset'

# Construct the correct path to the 'Osteoporosis' folder
Osteoporosis_folder = os.path.join(data_dir, 'Osteoporosis')

# Check if the directory exists
if os.path.exists(Osteoporosis_folder):
    print("Directory exists:", Osteoporosis_folder)
    Osteoporosis_path = os.listdir(Osteoporosis_folder)[0]
    print("First file in the directory:", Osteoporosis_path)
else:
    print(f"The directory {Osteoporosis_folder} does not exist.")
# Out:
# Directory exists: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Osteoporosis
# First file in the directory: Osteoporosis_120.jpg

# %%
import os

data_dir = r'/Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset'

# Correct way to concatenate paths
Osteoporosis_folder = os.path.join(data_dir, 'Osteoporosis')

# Now you can list files in the folder
Osteoporosis_path = os.listdir(Osteoporosis_folder)[0]

print(f"First file in the directory: {Osteoporosis_path}")
# Out:
# First file in the directory: Osteoporosis_120.jpg

# %%
os_images = os.path.join(data_dir, 'Osteoporosis', Osteoporosis_path)

# %%
imread(os_images).shape
# Out:
# (256, 128, 3)

# %%
plt.imshow(imread(os_images))

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.image import imread

# Ensure data_dir is defined correctly
data_dir = '/Users/atharvadumbre/.cache/kagglehub/datasets/sachinkumar413/osteoporosis-knee-dataset-preprocessed128x256/versions/1/'

# List contents of 'Osteoporosis Knee Dataset' directory
Osteoporosis_files = os.listdir(os.path.join(data_dir, 'Osteoporosis Knee Dataset'))

# Define the first file or subdirectory in the 'Osteoporosis' folder
Osteoporosis_path = Osteoporosis_files[0]

# Concatenate the full path to the file
os_images = os.path.join(data_dir, 'Osteoporosis Knee Dataset', Osteoporosis_path)

# Check if the path is a directory or file
if os.path.isdir(os_images):
    print(f"{os_images} is a directory.")
elif os.path.isfile(os_images):
    print(f"{os_images} is a file.")
    # Read and display the image using imread and plt.imshow
    image = imread(os_images)
    plt.imshow(image)
    plt.axis('off')  # Optional: Hide axes
    plt.show()
else:
    print(f"Invalid path: {os_images}")
# Out:
# /Users/atharvadumbre/.cache/kagglehub/datasets/sachinkumar413/osteoporosis-knee-dataset-preprocessed128x256/versions/1/Osteoporosis Knee Dataset/Osteoporosis is a directory.

# %% [markdown]
# ## More Visualisation on Osteoporosis images

# %%
data_dir = '/Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset'

# Assuming your images are inside 'Osteoporosis' subfolder
Osteoporosis_dir = os.path.join(data_dir, 'Osteoporosis')

# Get the list of image files (limit to first 5 for visualization)
image_files = os.listdir(Osteoporosis_dir)[:5]

# Create a subplot for 5 images
fig, axes = plt.subplots(1, 5, figsize=(15, 5))

# Iterate over the image files and display each one
for i, img_file in enumerate(image_files):
    img_path = os.path.join(Osteoporosis_dir, img_file)  # Get full image path
    img = imread(img_path)  # Read the image using imread
    axes[i].imshow(img)  # Display the image
    axes[i].axis('off')  # Hide axes for cleaner display
    axes[i].set_title(f"Osteoporosis Knee {i+1}")  # Set title for each image

# Adjust layout and show the images
plt.tight_layout()
plt.show()

# %% [markdown]
# # Visualizing Healthy images

# %%
n_path = os.listdir(os.path.join(data_dir, 'Normal'))[0]

# %%
n_images =data_dir+'Normal/'+n_path

# %%
import os
from matplotlib.image import imread
import matplotlib.pyplot as plt

# 1. Define the path to the DIRECTORY containing the images
normal_images_dir = '/Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal'

# 2. Get a list of all filenames in that directory
try:
    image_files = os.listdir(normal_images_dir)
except FileNotFoundError:
    print(f"Error: The directory was not found at '{normal_images_dir}'")
    image_files = []


# 3. Construct the full path for ONE image and read it
if image_files: # Make sure the directory is not empty
    # Create the full path to the first image file
    first_image_path = os.path.join(normal_images_dir, image_files[0])
    
    print(f"Attempting to read image: {first_image_path}")

    try:
        img = imread(first_image_path)
        print("Image shape:", img.shape)

        # Display the image to confirm
        plt.imshow(img)
        plt.title("First Image in Directory")
        plt.show()

    except Exception as e:
        print(f"Error reading file '{first_image_path}': {e}")
else:
    print(f"No image files found in the specified directory.")
# Out:
# Attempting to read image: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_55.jpg
# Image shape: (256, 128, 3)

# %%
# Loop through all files in the directory
for filename in image_files:
    # Check for common image file extensions
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
        full_path = os.path.join(normal_images_dir, filename)
        
        # Now you can process each image
        # For example: an_image = imread(full_path)
        print(f"Successfully located: {full_path}")
# Out:
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_55.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_41.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_128.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_69.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_100.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_114.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_96.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_82.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_83.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_97.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_115.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_101.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_68.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_129.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_40.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_54.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_42.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_56.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_117.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_103.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_81.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_95.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_94.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_80.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_102.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_116.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_57.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_43.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_112.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_106.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_47.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_53.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_84.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_90.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_91.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_85.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_52.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_46.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_107.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_113.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_105.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_111.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_78.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_139.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_50.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_44.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_93.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_87.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_86.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_92.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_45.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_51.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_138.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_79.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_110.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_104.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_36.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_22.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_163.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_177.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_176.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_162.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_23.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_37.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_148.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_21.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_35.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_174.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_160.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_8.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_9.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_161.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_175.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_34.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_20.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_149.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_18.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_171.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_165.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_24.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_30.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_159.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_158.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_31.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_25.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_164.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_170.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_19.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_166.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_172.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_33.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_27.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_26.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_32.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_173.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_167.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_17.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_142.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_156.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_181.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_3.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_180.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_157.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_143.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_16.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_169.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_14.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_155.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_28.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_141.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_182.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_183.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_140.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_29.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_154.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_15.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_168.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_150.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_39.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_144.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_178.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_11.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_4.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_5.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_186.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_10.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_179.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_145.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_38.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_151.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_147.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_153.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_12.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_184.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_7.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_6.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_185.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_13.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_152.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_146.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_74.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_109.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_60.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_121.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_48.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_135.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_134.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_49.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_120.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_61.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_108.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_75.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_63.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_77.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_136.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_122.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_88.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_89.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_123.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_137.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_76.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_62.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_133.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_127.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_66.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_72.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_99.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_98.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_73.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_67.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_126.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_132.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_124.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_59.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_130.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_71.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_118.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_65.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_64.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_119.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_70.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_131.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_58.jpg
# Successfully located: /Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal/Normal_125.jpg

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.image import imread

# Path to the dataset
data_dir = '/Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset'

# Paths to Osteoporosis and Normal directories
Osteoporosis_dir = os.path.join(data_dir, 'Osteoporosis')
Normal_dir = os.path.join(data_dir, 'Normal')

# Get the list of images from both directories
Osteoporosis_images = os.listdir(Osteoporosis_dir)[:5]
Normal_images = os.listdir(Normal_dir)[:5]

# Create subplots for Osteoporosis and Normal images (5 from each)
fig, axes = plt.subplots(2, 5, figsize=(15, 10))

# Display Osteoporosis images
for i, img_file in enumerate(Osteoporosis_images):
    img_path = os.path.join(Osteoporosis_dir, img_file)
    img = imread(img_path)
    axes[0, i].imshow(img)
    axes[0, i].axis('off')
    axes[0, i].set_title(f"Osteoporosis {i+1}")

# Display Normal images
for i, img_file in enumerate(Normal_images):
    img_path = os.path.join(Normal_dir, img_file)
    img = imread(img_path)
    axes[1, i].imshow(img)
    axes[1, i].axis('off')
    axes[1, i].set_title(f"Normal {i+1}")

# Adjust layout and show the images
plt.tight_layout()
plt.show()

# %%
# Get the full path of the first image from the Normal directory
n_path = os.path.join(Normal_dir, os.listdir(Normal_dir)[0])

# Read the image using imread
n_image = imread(n_path)

# Print the shape of the image
print(n_image.shape)
# Out:
# (256, 128, 3)

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

# Construct the full path to the first Normal image
n_images = os.path.join(Normal_dir, n_path)

# Read the image using imread
n_image = imread(n_images)

# Display the image using imshow
plt.imshow(n_image)
plt.axis('off')  # Hide the axes
plt.show()

# %%
plt.imshow(imread(n_images))

# %% [markdown]
# ## More Visualisation on healthy images

# %%
normal_dir = os.path.join(data_dir, 'Normal')
image_files = os.listdir(normal_dir)[:5]
fig, axes = plt.subplots(1, 5, figsize=(15, 5))  
for i, img_file in enumerate(image_files):
    img_path = os.path.join(normal_dir, img_file)
    img = imread(img_path)
    axes[i].imshow(img)
    axes[i].axis('off') 
    axes[i].set_title(f"Healthy Knee image {i+1}") 
plt.tight_layout()
plt.show()

# %%
# Define the directory paths for each image class folder
healthy_dirs = r'/Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Normal'
osteoporosis_dirs = r'/Users/atharvadumbre/Osteoporosis_knee_Classification-main/Osteoporosis Knee Dataset/Osteoporosis'

# %%
##  Looping through each folder with various file extensions and converting path of each image to a row 

healthy_dirs =healthy_dirs
osteoporosis_dirs=osteoporosis_dirs


filepaths = []
labels = []

dict_lists = [healthy_dirs, osteoporosis_dirs]
class_labels = ['Healthy', 'Osteoporosis']
image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".tiff")

for i, dir_list in enumerate(dict_lists):
    flist = os.listdir(dir_list)  
    for f in flist:
    
        if f.lower().endswith(image_extensions):  
            fpath = os.path.join(dir_list, f)  
            filepaths.append(fpath)  
            labels.append(class_labels[i])

# %%
# Creating  a DataFrame from the file paths and labels
Fseries = pd.Series(filepaths, name="filepaths")
Lseries = pd.Series(labels, name="labels")
knee_osteoporosis_data = pd.concat([Fseries, Lseries], axis=1)
knee_osteoporosis_df = pd.DataFrame(knee_osteoporosis_data)

# %%
knee_osteoporosis_df
# Out:
#                                              filepaths        labels
# 0    /Users/atharvadumbre/Osteoporosis_knee_Classif...       Healthy
# 1    /Users/atharvadumbre/Osteoporosis_knee_Classif...       Healthy
# 2    /Users/atharvadumbre/Osteoporosis_knee_Classif...       Healthy
# 3    /Users/atharvadumbre/Osteoporosis_knee_Classif...       Healthy
# 4    /Users/atharvadumbre/Osteoporosis_knee_Classif...       Healthy
# ..                                                 ...           ...
# 364  /Users/atharvadumbre/Osteoporosis_knee_Classif...  Osteoporosis
# 365  /Users/atharvadumbre/Osteoporosis_knee_Classif...  Osteoporosis
# 366  /Users/atharvadumbre/Osteoporosis_knee_Classif...  Osteoporosis
# 367  /Users/atharvadumbre/Osteoporosis_knee_Classif...  Osteoporosis
# 368  /Users/atharvadumbre/Osteoporosis_knee_Classif...  Osteoporosis
#
# [369 rows x 2 columns]

# %%
knee_osteoporosis_df.shape
# Out:
# (369, 2)

# %%
knee_osteoporosis_df['labels'].value_counts()
# Out:
# labels
# Healthy         185
# Osteoporosis    184
# Name: count, dtype: int64

# %% [markdown]
# ### My dataset lacks enough images to effectively train my model. To address this, I need to generate additional images using offline augmentation techniques

# %%
# Defining output folders for augmented images
output_dir = "./augmented_data"
classes = ["Healthy", "Osteoporosis"]
for class_name in classes:
    class_path = os.path.join(output_dir, class_name)
    os.makedirs(class_path, exist_ok=True)

# %%
def augment_and_save(image_path, save_dir, base_name):
    """Apply augmentations and save images."""
    image = Image.open(image_path)
    
    # Rotation
    for angle in [90, 180, 270]:
        rotated = image.rotate(angle)
        rotated.save(os.path.join(save_dir, f"{base_name}_rot{angle}.jpg"))
    
    # Flipping
    flipped = image.transpose(Image.FLIP_LEFT_RIGHT)
    flipped.save(os.path.join(save_dir, f"{base_name}_flip.jpg"))
    
    # Brightness adjustments
    enhancer = ImageEnhance.Brightness(image)
    for factor in [0.5, 1.5]:  # Darker and brighter versions
        brightened = enhancer.enhance(factor)
        brightened.save(os.path.join(save_dir, f"{base_name}_bright{factor}.jpg"))
# Shear transformations
    #for shear in [0.2, 0.4]:
        #sheared = image.transform((width, height), Image.AFFINE, (1, shear, 0, shear, 1, 0))
        #sheared.save(os.path.join(save_dir, f"{base_name}_shear{shear}.jpg"))
    
    # Adding noise
    noise_factor = 0.05
    np_img = np.array(image)
    noise = np.random.normal(0, noise_factor, np_img.shape)
    noisy_img = np_img + noise * 255  # Scale by 255 for RGB
    noisy_img = np.clip(noisy_img, 0, 255).astype(np.uint8)
    noisy_image = Image.fromarray(noisy_img)
    noisy_image.save(os.path.join(save_dir, f"{base_name}_noise.jpg"))
    
    # Random Color Jitter (Random adjustments to the image's contrast, brightness, and saturation)
    enhancer_contrast = ImageEnhance.Contrast(image)
    enhancer_saturation = ImageEnhance.Color(image)
    for contrast_factor in [0.8, 1.2]:
        for saturation_factor in [0.8, 1.2]:
            contrast_enhanced = enhancer_contrast.enhance(contrast_factor)
            final_image = enhancer_saturation.enhance(saturation_factor)
            final_image.save(os.path.join(save_dir, f"{base_name}_contrast{contrast_factor}_saturation{saturation_factor}.jpg"))
# Loop through the DataFrame and apply augmentations
for index, row in knee_osteoporosis_df.iterrows():
    img_path = row["filepaths"]
    label = row["labels"]
    
    save_dir = os.path.join(output_dir, label)
    base_name = os.path.splitext(os.path.basename(img_path))[0]
    augment_and_save(img_path, save_dir, base_name)

# %%
# Rebuild DataFrame for augmented data
augmented_filepaths = []
augmented_labels = []

# Loop through augmented folders
for label in classes:
    class_folder = os.path.join(output_dir, label)
    files = os.listdir(class_folder)
    
    for file in files:
        augmented_filepaths.append(os.path.join(class_folder, file))
        augmented_labels.append(label)

# Create a DataFrame
augmented_df = pd.DataFrame({
    "filepaths": augmented_filepaths,
    "labels": augmented_labels
})

# %%
augmented_df
# Out:
#                                               filepaths        labels
# 0         ./augmented_data/Healthy/Normal_147_rot90.jpg       Healthy
# 1     ./augmented_data/Healthy/Normal_144_contrast0....       Healthy
# 2     ./augmented_data/Healthy/Normal_143_bright0.5.jpg       Healthy
# 3      ./augmented_data/Healthy/Normal_45_bright1.5.jpg       Healthy
# 4     ./augmented_data/Healthy/Normal_95_contrast0.8...       Healthy
# ...                                                 ...           ...
# 4054  ./augmented_data/Osteoporosis/Osteoporosis_80_...  Osteoporosis
# 4055  ./augmented_data/Osteoporosis/Osteoporosis_123...  Osteoporosis
# 4056  ./augmented_data/Osteoporosis/Osteoporosis_71_...  Osteoporosis
# 4057  ./augmented_data/Osteoporosis/Osteoporosis_175...  Osteoporosis
# 4058  ./augmented_data/Osteoporosis/Osteoporosis_110...  Osteoporosis
#
# [4059 rows x 2 columns]

# %%
augmented_df.shape
# Out:
# (4059, 2)

# %%
augmented_df['labels'].value_counts()
# Out:
# labels
# Healthy         2035
# Osteoporosis    2024
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# Your original augmented dataframe
# augmented_df = ...

# --- Step 1: Split into training+validation (80%) and test (20%) ---
# We keep the stratification on the original dataframe's labels
train_val_df, test_df = train_test_split(augmented_df,
                                         test_size=0.20,
                                         stratify=augmented_df['labels'],
                                         random_state=42)

# --- Step 2: Split the train_val_df into final training (80% of 80% = 64%) and validation (20% of 80% = 16%) ---
# Note: test_size=0.25 of the 80% gives a 20% validation set relative to the original size
train_df, valid_df = train_test_split(train_val_df,
                                      test_size=0.25, # 25% of the 80% train_val set
                                      stratify=train_val_df['labels'],
                                      random_state=42)

# --- Verification ---
print("Augmented DF shape:", augmented_df.shape)
print("Augmented DF class distribution:\n", augmented_df['labels'].value_counts(normalize=True))
print("\\n---")
print("Train DF shape:", train_df.shape)
print("Train DF class distribution:\n", train_df['labels'].value_counts(normalize=True))
print("\\n---")
print("Validation DF shape:", valid_df.shape)
print("Validation DF class distribution:\n", valid_df['labels'].value_counts(normalize=True))
print("\\n---")
print("Test DF shape:", test_df.shape)
print("Test DF class distribution:\n", test_df['labels'].value_counts(normalize=True))
# Out:
# Augmented DF shape: (4059, 2)
# Augmented DF class distribution:
#  labels
# Healthy         0.501355
# Osteoporosis    0.498645
# Name: proportion, dtype: float64
# \n---
# Train DF shape: (2435, 2)
# Train DF class distribution:
#  labels
# Healthy         0.501437
# Osteoporosis    0.498563
# Name: proportion, dtype: float64
# \n---
# Validation DF shape: (812, 2)
# Validation DF class distribution:
#  labels
# Healthy         0.501232
# Osteoporosis    0.498768
# Name: proportion, dtype: float64
# \n---
# Test DF shape: (812, 2)
# Test DF class distribution:
#  labels
# Healthy         0.501232
# Osteoporosis    0.498768
# Name: proportion, dtype: float64

# %%
# Split the DataFrame into train and test sets and stratify the label to preserve my class distribution because  im going to perform flow from dataframe 

train_df, test_df = train_test_split(augmented_df,  test_size=0.2, stratify=augmented_df['labels'], random_state=42)

# %%
# Creating ImageDataGenerators to normalize and rescale my images

train_datagen = ImageDataGenerator(rescale=1./255)  
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Define the target size and batch size

TARGET_SIZE = (150, 150)  
BATCH_SIZE = 32

# %% [markdown]
# ### Creating my Train and test generators

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 1. Define the training ImageDataGenerator with augmentation parameters
train_datagen = ImageDataGenerator(
    rescale=1./255,             # Normalize pixel values to [0, 1]
    rotation_range=20,          # Randomly rotate images by up to 20 degrees
    width_shift_range=0.1,      # Randomly shift images horizontally by up to 10%
    height_shift_range=0.1,     # Randomly shift images vertically by up to 10%
    zoom_range=0.1,             # Randomly zoom in on images by up to 10%
    horizontal_flip=True,       # Randomly flip images horizontally
    fill_mode='nearest'         # How to fill in new pixels that may appear
)

# 2. Your flow_from_dataframe call remains the same
# It will now use the generator with the augmentations defined above.
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filepaths',
    y_col='labels',
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=True
)
# Out:
# Found 2435 validated image filenames belonging to 2 classes.

# %%
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filepaths',  
    y_col='labels',     
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',  
    shuffle=True         
)
# Out:
# Found 3273 validated image filenames belonging to 2 classes.

# %%
# creating my test generator. it is not good to shuffle the test data 

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filepaths',
    y_col='labels',
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False 
)
# Out:
# Found 812 validated image filenames belonging to 2 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential([
    # --- First Convolutional Block ---
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(150, 150, 3)),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25), # Dropout for regularization

    # --- Second Convolutional Block ---
    # Increased filters to learn more complex features
    Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    # --- Third Convolutional Block ---
    Conv2D(filters=128, kernel_size=(3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    # --- Classifier Head ---
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5), # Higher dropout before the final layer
    Dense(1, activation='sigmoid') # Final output neuron
])

# After defining the model, you need to compile it
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# # Define a simple CNN model

# model = Sequential([Conv2D(filters= 32, kernel_size= (3, 3), activation='relu', input_shape=(150, 150, 3)),
#            MaxPooling2D(pool_size=(2, 2)),
#           Flatten(),
#           Dense(128, activation='relu'), #128: Number of neurons in this layer.
#           Dense(1, activation='sigmoid') #1: Single neuron output (since this is a binary classification task).
# ])

# %%
# Compile the model

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model

history = model.fit(train_generator,validation_data=test_generator,epochs=50)
# Out:
# Epoch 1/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 58s 723ms/step - accuracy: 0.5355 - loss: 3.3166 - val_accuracy: 0.3966 - val_loss: 4.3770
# Epoch 2/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 721ms/step - accuracy: 0.5802 - loss: 0.7020 - val_accuracy: 0.5086 - val_loss: 8.4394
# Epoch 3/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 719ms/step - accuracy: 0.5766 - loss: 0.6680 - val_accuracy: 0.5111 - val_loss: 4.7532
# Epoch 4/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.5953 - loss: 0.6631 - val_accuracy: 0.4187 - val_loss: 1.5853
# Epoch 5/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 729ms/step - accuracy: 0.5860 - loss: 0.6622 - val_accuracy: 0.4384 - val_loss: 1.6299
# Epoch 6/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 726ms/step - accuracy: 0.5971 - loss: 0.6647 - val_accuracy: 0.5000 - val_loss: 1.3776
# Epoch 7/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 725ms/step - accuracy: 0.5827 - loss: 0.6587 - val_accuracy: 0.5259 - val_loss: 1.1861
# Epoch 8/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 73s 954ms/step - accuracy: 0.5769 - loss: 0.6591 - val_accuracy: 0.5850 - val_loss: 1.5583
# Epoch 9/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 728ms/step - accuracy: 0.5984 - loss: 0.6414 - val_accuracy: 0.6232 - val_loss: 0.6522
# Epoch 10/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 730ms/step - accuracy: 0.5482 - loss: 0.6475 - val_accuracy: 0.6576 - val_loss: 0.6196
# Epoch 11/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 60s 778ms/step - accuracy: 0.5970 - loss: 0.6525 - val_accuracy: 0.6823 - val_loss: 0.5663
# Epoch 12/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 728ms/step - accuracy: 0.6088 - loss: 0.6407 - val_accuracy: 0.6429 - val_loss: 0.8373
# Epoch 13/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 729ms/step - accuracy: 0.6222 - loss: 0.6275 - val_accuracy: 0.6466 - val_loss: 0.9161
# Epoch 14/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 57s 733ms/step - accuracy: 0.6355 - loss: 0.6165 - val_accuracy: 0.6773 - val_loss: 0.6178
# Epoch 15/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 66s 851ms/step - accuracy: 0.6351 - loss: 0.6150 - val_accuracy: 0.6983 - val_loss: 0.5754
# Epoch 16/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 57s 733ms/step - accuracy: 0.6432 - loss: 0.6604 - val_accuracy: 0.5271 - val_loss: 0.7620
# Epoch 17/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 57s 738ms/step - accuracy: 0.6454 - loss: 0.6359 - val_accuracy: 0.7044 - val_loss: 0.6778
# Epoch 18/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 61s 795ms/step - accuracy: 0.6576 - loss: 0.6034 - val_accuracy: 0.5874 - val_loss: 3.0751
# Epoch 19/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 59s 766ms/step - accuracy: 0.6488 - loss: 0.6142 - val_accuracy: 0.7118 - val_loss: 0.6410
# Epoch 20/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 57s 735ms/step - accuracy: 0.6257 - loss: 0.6290 - val_accuracy: 0.6478 - val_loss: 0.6655
# Epoch 21/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 59s 760ms/step - accuracy: 0.6669 - loss: 0.6064 - val_accuracy: 0.6810 - val_loss: 0.6211
# Epoch 22/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 63s 814ms/step - accuracy: 0.6653 - loss: 0.5865 - val_accuracy: 0.6835 - val_loss: 0.5783
# Epoch 23/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 729ms/step - accuracy: 0.6476 - loss: 0.6105 - val_accuracy: 0.7057 - val_loss: 0.6843
# Epoch 24/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 725ms/step - accuracy: 0.6598 - loss: 0.6063 - val_accuracy: 0.7315 - val_loss: 0.5774
# Epoch 25/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 64s 836ms/step - accuracy: 0.6639 - loss: 0.5924 - val_accuracy: 0.7155 - val_loss: 0.7053
# Epoch 26/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 726ms/step - accuracy: 0.6720 - loss: 0.6001 - val_accuracy: 0.7155 - val_loss: 0.6432
# Epoch 27/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 723ms/step - accuracy: 0.6610 - loss: 0.5839 - val_accuracy: 0.7180 - val_loss: 0.5755
# Epoch 28/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 726ms/step - accuracy: 0.6766 - loss: 0.5935 - val_accuracy: 0.7167 - val_loss: 0.5385
# Epoch 29/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 725ms/step - accuracy: 0.6791 - loss: 0.5766 - val_accuracy: 0.7340 - val_loss: 0.5496
# Epoch 30/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 58s 756ms/step - accuracy: 0.6754 - loss: 0.5989 - val_accuracy: 0.4988 - val_loss: 0.8486
# Epoch 31/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 59s 761ms/step - accuracy: 0.6254 - loss: 0.6349 - val_accuracy: 0.7192 - val_loss: 0.5447
# Epoch 32/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 60s 777ms/step - accuracy: 0.6704 - loss: 0.6036 - val_accuracy: 0.7143 - val_loss: 0.5436
# Epoch 33/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 61s 790ms/step - accuracy: 0.6757 - loss: 0.5860 - val_accuracy: 0.7266 - val_loss: 0.5279
# Epoch 34/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 58s 755ms/step - accuracy: 0.6821 - loss: 0.5627 - val_accuracy: 0.7081 - val_loss: 0.5481
# Epoch 35/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 59s 760ms/step - accuracy: 0.6876 - loss: 0.5547 - val_accuracy: 0.6736 - val_loss: 0.5793
# Epoch 36/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 59s 763ms/step - accuracy: 0.6891 - loss: 0.5656 - val_accuracy: 0.6626 - val_loss: 0.6953
# Epoch 37/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 58s 752ms/step - accuracy: 0.6778 - loss: 0.5899 - val_accuracy: 0.6970 - val_loss: 0.5458
# Epoch 38/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 59s 761ms/step - accuracy: 0.6634 - loss: 0.5963 - val_accuracy: 0.7241 - val_loss: 0.5286
# Epoch 39/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 59s 771ms/step - accuracy: 0.6868 - loss: 0.5873 - val_accuracy: 0.7574 - val_loss: 0.5213
# Epoch 40/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 57s 740ms/step - accuracy: 0.7111 - loss: 0.5587 - val_accuracy: 0.7525 - val_loss: 0.5241
# Epoch 41/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 57s 740ms/step - accuracy: 0.6707 - loss: 0.5799 - val_accuracy: 0.7315 - val_loss: 0.5904
# Epoch 42/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 57s 739ms/step - accuracy: 0.6918 - loss: 0.5753 - val_accuracy: 0.7672 - val_loss: 0.5625
# Epoch 43/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 57s 746ms/step - accuracy: 0.7240 - loss: 0.5454 - val_accuracy: 0.7697 - val_loss: 0.4951
# Epoch 44/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 57s 735ms/step - accuracy: 0.6911 - loss: 0.5618 - val_accuracy: 0.7352 - val_loss: 0.5330
# Epoch 45/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 58s 746ms/step - accuracy: 0.7209 - loss: 0.5464 - val_accuracy: 0.7020 - val_loss: 0.5497
# Epoch 46/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 57s 738ms/step - accuracy: 0.6735 - loss: 0.5838 - val_accuracy: 0.7451 - val_loss: 0.5099
# Epoch 47/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 57s 736ms/step - accuracy: 0.7044 - loss: 0.5612 - val_accuracy: 0.7229 - val_loss: 0.5192
# Epoch 48/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 60s 784ms/step - accuracy: 0.6790 - loss: 0.5705 - val_accuracy: 0.7475 - val_loss: 0.5221
# Epoch 49/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 57s 735ms/step - accuracy: 0.6976 - loss: 0.5684 - val_accuracy: 0.7586 - val_loss: 0.4964
# Epoch 50/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 56s 727ms/step - accuracy: 0.7118 - loss: 0.5587 - val_accuracy: 0.7094 - val_loss: 0.5670

# %%
# Plot the training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# #### please  note that this model can be improved to get a better accuracy. The model is  straightforward. For better performance increase the following

# %% [markdown]
# ### Increase the Number of Layers,
# ### increase Filter Sizes,
# ### Use Dropout Layers,
# ###  Adjust Kernel Size,
# adjust learning rate

# %%
test_generator.class_indices
# Out:
# {'Healthy': 0, 'Osteoporosis': 1}

# %%
# Get predictions for the test data
predictions = model.predict(test_generator)

predictions_binary = (predictions > 0.5)

true_labels = test_generator.classes

# Print the classification report
print(classification_report(true_labels, predictions_binary))
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.44      0.61       407
#            1       0.64      0.98      0.77       405
#
#     accuracy                           0.71       812
#    macro avg       0.79      0.71      0.69       812
# weighted avg       0.79      0.71      0.69       812

# %% [markdown]
# ## Saving and loading the model

# %%
# Save the model
model.save('cnn_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save('/Users/atharvadumbre/Osteoporosis_knee_Classification-main/artifacts/cnn_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Clear optimizer state
model.optimizer = None

# Save the model
model.save('cnn_model.keras')

# %%
# Load the model
cnn_model = load_model('/Users/atharvadumbre/Osteoporosis_knee_Classification-main/artifacts/cnn_model.keras')

# %% [markdown]
# ## Testing the loaded cnn model with a healthy knee image path

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Path to the image
image_path = '/Users/atharvadumbre/Osteoporosis_knee_Classification-main/augmented_data/Healthy/Normal_2_bright0.5.jpg'
img = load_img(image_path, target_size=(150, 150))  # Resize to (128, 256)
img_array = img_to_array(img)

img_array = img_array / 255.0

img_array = np.expand_dims(img_array, axis=0)

# %%
img_array.shape
# Out:
# (1, 150, 150, 3)

# %%
from tensorflow.keras.models import load_model

# Load the existing model (adjust the path as needed)
cnn_model = load_model('/Users/atharvadumbre/Osteoporosis_knee_Classification-main/artifacts/cnn_model.keras', compile=False)  # Disable optimizer compilation if necessary

# %%
predictions = cnn_model.predict(img_array)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step

# %%
predictions
# Out:
# array([[1.06102426e-07]], dtype=float32)

# %%
test_generator.class_indices
# Out:
# {'Healthy': 0, 'Osteoporosis': 1}
